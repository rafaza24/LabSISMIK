# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaza24/LabSISMIK/blob/main/Perbandingan_Solusi_Numerik_Menggunakan_Metode_Euler_dan_Heun.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def exact_solution(t):
    return np.exp(-2 * t)

# %%
def euler_method(f, y0, t):
    y = np.zeros(len(t))
    y[0] = y0
    for i in range(1, len(t)):
        dt = t[i] - t[i-1]
        y[i] = y[i-1] + dt * f(t[i-1], y[i-1])
    return y

# %%
def heun_method(f, y0, t):
    y = np.zeros(len(t))
    y[0] = y0
    for i in range(1, len(t)):
        dt = t[i] - t[i-1]
        y_pred = y[i-1] + dt * f(t[i-1], y[i-1])  # Euler prediction
        y[i] = y[i-1] + dt * (f(t[i-1], y[i-1]) + f(t[i], y_pred)) / 2  # Heun correction
    return y

# %%
# ODE definition: y' = -2y
def f(t, y):
    return -2 * y

# %%
# ODE definition: y' = 5x
def f(t, y):
    return -2 * y

# %%
# Parameters
y0 = 1
t0, t_end = 0, 5
n_points = 10
t = np.linspace(t0, t_end, n_points)

# %%
t
# Out:
# array([0.        , 0.55555556, 1.11111111, 1.66666667, 2.22222222,
#        2.77777778, 3.33333333, 3.88888889, 4.44444444, 5.        ])

# %%
# Solutions
y_exact = exact_solution(t)
y_euler = euler_method(f, y0, t)
y_heun = heun_method(f, y0, t)

# %%
y_exact
# Out:
# array([1.00000000e+00, 3.29192988e-01, 1.08368023e-01, 3.56739933e-02,
#        1.17436285e-02, 3.86592014e-03, 1.27263380e-03, 4.18942123e-04,
#        1.37912809e-04, 4.53999298e-05])

# %%
y_euler
# Out:
# array([ 1.00000000e+00, -1.11111111e-01,  1.23456790e-02, -1.37174211e-03,
#         1.52415790e-04, -1.69350878e-05,  1.88167642e-06, -2.09075158e-07,
#         2.32305731e-08, -2.58117479e-09])

# %%
y_heun
# Out:
# array([1.        , 0.50617284, 0.25621094, 0.12968702, 0.06564405,
#        0.03322723, 0.01681872, 0.00851318, 0.00430914, 0.00218117])

# %%
plt.figure(figsize=(10, 6))
plt.plot(t, y_exact, label="Exact Solution", marker="*", color="black", linestyle="--")
plt.plot(t, y_euler, label="Euler Method", marker="o", linestyle="-")
plt.plot(t, y_heun, label="Heun Method",  linestyle="-")
plt.xlabel("t")
plt.ylabel("y(t)")
plt.title("Comparison of Numerical Methods")
plt.legend()
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# Definisi fungsi PDB
def dy_dt(t, y):
    return -2 * y

# Kondisi awal
y0 = [1]
t_span = (0, 5)  # Interval waktu
t_eval = np.linspace(t_span[0], t_span[1], 100)  # Titik evaluasi

# Menyelesaikan PDB
sol = solve_ivp(dy_dt, t_span, y0, t_eval=t_eval)

# Plot solusi
plt.figure(figsize=(8, 5))
plt.plot(t, y_exact, label="Exact Solution", marker="*", color="black", linestyle="--")
plt.plot(sol.t, sol.y[0], label=r"$\frac{dy}{dt} = -2y$", color="blue")
plt.title("Solusi PDB", fontsize=14)
plt.xlabel("t (waktu)", fontsize=12)
plt.ylabel("y (solusi)", fontsize=12)
plt.legend(fontsize=12)
plt.grid()
plt.show()
